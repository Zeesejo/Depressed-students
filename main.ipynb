# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including pandas and numpy.

# %%
# Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the Dataset
# Load the dataset into a pandas DataFrame.

# %%
# Load the Dataset
# Load the dataset into a pandas DataFrame
df = pd.read_csv('dataset-depression-stud\Student Depression Dataset.csv')

# Display the first few rows of the dataset
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %% [markdown]
# # Inspect Dataset Structure
# Use functions like head(), tail(), and info() to inspect the structure of the dataset.

# %%
# Inspect Dataset Structure

# Display the first few rows of the dataset
df.head()

# Display the last few rows of the dataset
df.tail()

# Display a concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %% [markdown]
# # Check Dataset Shape
# Use the shape attribute to check the dimensions of the dataset.

# %%
# Check Dataset Shape

# Use the shape attribute to check the dimensions of the dataset
dataset_shape = df.shape
dataset_shape
# Out:
# (27901, 18)

# %% [markdown]
# # Generate Summary Statistics
# Use the describe() function to generate summary statistics for the dataset.

# %%
# Generate Summary Statistics

# Use the describe() function to generate summary statistics for the dataset
summary_statistics = df.describe()
summary_statistics
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %% [markdown]
# Distribution of depression status across genders

# %%
# Distribution of depression status across genders
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Gender', hue='Depression')
plt.title('Distribution of Depression Status Across Genders')
plt.show()

# %% [markdown]
# Distribution of depression status across age groups

# %%
# Distribution of depression status across age groups
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', hue='Depression', multiple='stack', bins=20)
plt.title('Distribution of Depression Status Across Age Groups')
plt.show()

# %% [markdown]
# Distribution of depression status across CGPA

# %%
# Distribution of depression status across CGPA
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='CGPA', hue='Depression', multiple='stack', bins=20)
plt.title('Distribution of Depression Status Across CGPA')
plt.show()

# %% [markdown]
# # Encode Categorical Variables
# Convert categorical variables to numerical values.

# %%
# Encode Categorical Variables
df_encoded = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# # Correlation Heatmap
# Generate a correlation heatmap of features with depression status.

# %%
# Correlation Heatmap
import seaborn as sns
import matplotlib.pyplot as plt

# Encode categorical variables
df_encoded = pd.get_dummies(df, drop_first=True)

# Generate correlation matrix
plt.figure(figsize=(12, 8))
correlation_matrix = df_encoded.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Features with Depression Status')
plt.show()

# %% [markdown]
# Trends in lifestyle habits (e.g., sleep, diet) vs. depression.

# %%
# Trends in Sleep Duration vs. Depression
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Sleep Duration', hue='Depression')
plt.title('Trends in Sleep Duration vs. Depression')
plt.show()

# Trends in Dietary Habits vs. Depression
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Dietary Habits', hue='Depression')
plt.title('Trends in Dietary Habits vs. Depression')
plt.show()

# %% [markdown]
# # Handle missing or inconsistent data

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)

# Drop rows with missing values
df_cleaned = df.dropna()

# Alternatively, fill missing values with a specific value (e.g., mean of the column)
# df_filled = df.fillna(df.mean())

# Display the cleaned dataset
df_cleaned.head()
# Out:
# Missing values in each column:
#  id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# Initialize a LabelEncoder object
scaler = MinMaxScaler()

# Normalize the CGPA column and Sleep Duration column
df_encoded[['CGPA', 'Work/Study Hours']] = scaler.fit_transform(df_encoded[['CGPA', 'Work/Study Hours']])

# Display the normalized dataset
df_encoded.head()
# Out:
#    id   Age  Academic Pressure  Work Pressure   CGPA  Study Satisfaction  \
# 0   2  33.0                5.0            0.0  0.897                 2.0
# 1   8  24.0                2.0            0.0  0.590                 5.0
# 2  26  31.0                3.0            0.0  0.703                 5.0
# 3  30  28.0                3.0            0.0  0.559                 2.0
# 4  32  25.0                4.0            0.0  0.813                 3.0
#
#    Job Satisfaction  Work/Study Hours  Financial Stress  Depression  ...  \
# 0               0.0          0.250000               1.0           1  ...
# 1               0.0          0.250000               2.0           0  ...
# 2               0.0          0.750000               1.0           0  ...
# 3               0.0          0.333333               5.0           1  ...
# 4               0.0          0.083333               1.0           0  ...
#
#    Degree_MBBS  Degree_MCA  Degree_MD  Degree_ME  Degree_MHM  Degree_MSc  \
# ...

# %% [markdown]
# One hot encoding

# %%
# Encode categorical features
df_encoded = pd.get_dummies(df, columns=['Gender', 'City', 'Profession', 'Sleep Duration', 'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness'], drop_first=True)

# Display the encoded dataset
df_encoded.head()
# Out:
#    id   Age  Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0   2  33.0                5.0            0.0  8.97                 2.0
# 1   8  24.0                2.0            0.0  5.90                 5.0
# 2  26  31.0                3.0            0.0  7.03                 5.0
# 3  30  28.0                3.0            0.0  5.59                 2.0
# 4  32  25.0                4.0            0.0  8.13                 3.0
#
#    Job Satisfaction  Work/Study Hours  Financial Stress  Depression  ...  \
# 0               0.0               3.0               1.0           1  ...
# 1               0.0               3.0               2.0           0  ...
# 2               0.0               9.0               1.0           0  ...
# 3               0.0               4.0               5.0           1  ...
# 4               0.0               1.0               1.0           0  ...
#
#    Degree_MBBS  Degree_MCA  Degree_MD  Degree_ME  Degree_MHM  Degree_MSc  \
# ...

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
# Visualize the significant features  on Chi-Square test

plt.figure(figsize=(10, 6))
plt.barh(list(chi2_results.keys()), list(chi2_results.values()))
plt.xlabel('P-value')
plt.ylabel('Features')
plt.title('Significant Features Based on Chi-Square Test')
plt.show()

# Filter features with high correlation matrix with the target variable
correlation_with_target = correlation_matrix['Depression'].drop('Depression')
important_numerical_features = correlation_with_target[abs(correlation_with_target) > 0.1]

# Visualize important numerical features based on correlation
plt.figure(figsize=(10, 6))
important_numerical_features.sort_values().plot(kind='barh')
plt.xlabel('Correlation with Depression')
plt.ylabel('Features')
plt.title('Important Numerical Features Based on Correlation with Depression')
plt.show()

# %%
# Scatter plot to visualize the relationship between CGPA and depression
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='CGPA', y='Depression')
plt.title('Relationship between CGPA and Depression')
plt.xlabel('CGPA')
plt.ylabel('Depression')
plt.show()

# Scatter plot to visualize the relationship between Age and depression
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Age', y='Depression')
plt.title('Relationship between Age and Depression')
plt.xlabel('Age')
plt.ylabel('Depression')
plt.show()
# Calculate and print correlation coefficients for all the relationships
correlation_coefficients = {
    'CGPA vs Depression': df['CGPA'].corr(df['Depression']),
    'Age vs Depression': df['Age'].corr(df['Depression']),
    'Financial Stress vs Depression': df['Financial Stress'].corr(df['Depression']),
    'Work/Study Hours vs Depression': df['Work/Study Hours'].corr(df['Depression'])
}

for relation, coefficient in correlation_coefficients.items():
    print(f"Correlation coefficient for {relation}: {coefficient}")
# Scatter plot to visualize the relationship between Financial Stress and depression
plt.figure(figsize=(10, 6))
correlation_coefficient = df['Financial Stress'].corr(df['Depression'])
print(f"Correlation coefficient between Financial Stress and Depression: {correlation_coefficient}")
sns.scatterplot(data=df, x='Financial Stress', y='Depression')
plt.title('Relationship between Financial Stress and Depression')
plt.xlabel('Financial Stress')
plt.ylabel('Depression')
plt.show()

# Scatter plot to visualize the relationship between Work/Study Hours and depression
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Work/Study Hours', y='Depression')
plt.title('Relationship between Work/Study Hours and Depression')
plt.xlabel('Work/Study Hours')
plt.ylabel('Depression')
plt.show()
# Out:
# Correlation coefficient for CGPA vs Depression: 0.0222104703444617
# Correlation coefficient for Age vs Depression: -0.2264220409016654
# Correlation coefficient for Financial Stress vs Depression: 0.3635914288437021
# Correlation coefficient for Work/Study Hours vs Depression: 0.20856283111609364
# Correlation coefficient between Financial Stress and Depression: 0.3635914288437021

# %%
# Create a new feature 'Stress Level' by combining 'Academic Pressure' and 'Work Pressure'
df['Stress Level'] = df['Academic Pressure'] + df['Work Pressure']

# Create a new feature 'Satisfaction Level' by combining 'Study Satisfaction' and 'Job Satisfaction'
df['Satisfaction Level'] = df['Study Satisfaction'] + df['Job Satisfaction']

# Create a new feature 'Health Index' by combining 'Sleep Duration' and 'Dietary Habits'
# For simplicity, let's assume 'Sleep Duration' and 'Dietary Habits' are already encoded numerically
df['Health Index'] = df['Sleep Duration'] + df['Dietary Habits']

# Display the first few rows of the updated dataset
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  ...  \
# 0            0.0  8.97                 2.0               0.0  ...
# 1            0.0  5.90                 5.0               0.0  ...
# 2            0.0  7.03                 5.0               0.0  ...
# 3            0.0  5.59                 2.0               0.0  ...
# 4            0.0  8.13                 3.0               0.0  ...
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy  B.Pharm                                   Yes
# ...

# %%
# Discretize Age into groups
age_bins = [0, 18, 25, 35, 50, 60]
age_labels = ['0-18', '19-25', '26-35', '36-50', '51-60']
df['Age Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

# Display the first few rows of the updated dataset
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  ...   Degree  \
# 0            0.0  8.97                 2.0               0.0  ...  B.Pharm
# 1            0.0  5.90                 5.0               0.0  ...      BSc
# 2            0.0  7.03                 5.0               0.0  ...       BA
# 3            0.0  5.59                 2.0               0.0  ...      BCA
# 4            0.0  8.13                 3.0               0.0  ...   M.Tech
#
#   Have you ever had suicidal thoughts ? Work/Study Hours Financial Stress  \
# ...
